# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df19=pd.read_csv(r"D:\MBA\Internship\Data Collection\agri report data\ALL.csv")

# %%
df19
# Out:
#         Sl no. District Name Market Name          Commodity  \
# 0            1    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 1            2    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 2            3    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 3            4    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 4            5    Chhindwara  Chhindwara  Cinamon(Dalchini)
# ...        ...           ...         ...                ...
# 102028  102029       Nanital    Haldwani    Corriander seed
# 102029  102030       Nanital    Haldwani    Corriander seed
# 102030  102031       Nanital    Haldwani    Corriander seed
# 102031  102032       Nanital    Haldwani    Corriander seed
# 102032  102033       Nanital    Haldwani    Corriander seed
#
#                   Variety Grade  Min Price (Rs./Quintal)  \
# 0       Cinamon(Dalchini)   FAQ                   3500.0
# 1                   Other   FAQ                   3550.0
# 2                   Other   FAQ                   3000.0
# ...

# %%
df19.head()
# Out:
#    Sl no. District Name Market Name          Commodity            Variety  \
# 0       1    Chhindwara  Chhindwara  Cinamon(Dalchini)  Cinamon(Dalchini)
# 1       2    Chhindwara  Chhindwara  Cinamon(Dalchini)              Other
# 2       3    Chhindwara  Chhindwara  Cinamon(Dalchini)              Other
# 3       4    Chhindwara  Chhindwara  Cinamon(Dalchini)              Other
# 4       5    Chhindwara  Chhindwara  Cinamon(Dalchini)              Other
#
#   Grade  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# 0   FAQ                   3500.0                   3500.0
# 1   FAQ                   3550.0                   3550.0
# 2   FAQ                   3000.0                   3000.0
# 3   FAQ                   3400.0                   3400.0
# 4   FAQ                   3300.0                   3331.0
#
#    Modal Price (Rs./Quintal) Price Date
# 0                     3500.0  31-Oct-23
# 1                     3550.0  02-Oct-23
# 2                     3000.0  02-Aug-23
# ...

# %%
df19.tail
# Out:
# <bound method NDFrame.tail of         Sl no. District Name Market Name          Commodity  \
# 0            1    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 1            2    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 2            3    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 3            4    Chhindwara  Chhindwara  Cinamon(Dalchini)
# 4            5    Chhindwara  Chhindwara  Cinamon(Dalchini)
# ...        ...           ...         ...                ...
# 102028  102029       Nanital    Haldwani    Corriander seed
# 102029  102030       Nanital    Haldwani    Corriander seed
# 102030  102031       Nanital    Haldwani    Corriander seed
# 102031  102032       Nanital    Haldwani    Corriander seed
# 102032  102033       Nanital    Haldwani    Corriander seed
#
#                   Variety Grade  Min Price (Rs./Quintal)  \
# 0       Cinamon(Dalchini)   FAQ                   3500.0
# 1                   Other   FAQ                   3550.0
# ...

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102033 entries, 0 to 102032
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Sl no.                     102033 non-null  int64
#  1   District Name              102033 non-null  object
#  2   Market Name                102033 non-null  object
#  3   Commodity                  102033 non-null  object
#  4   Variety                    102033 non-null  object
#  5   Grade                      102033 non-null  object
#  6   Min Price (Rs./Quintal)    102033 non-null  float64
#  7   Max Price (Rs./Quintal)    102033 non-null  float64
#  8   Modal Price (Rs./Quintal)  102033 non-null  float64
#  9   Price Date                 102033 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 7.8+ MB

# %%
df19.shape
# Out:
# (102033, 10)

# %%
df19.describe()
# Out:
#               Sl no.  Min Price (Rs./Quintal)  Max Price (Rs./Quintal)  \
# count  102033.000000            102033.000000            102033.000000
# mean    51017.000000             12869.116389             17748.857559
# std     29454.534345             17050.109623             24457.500454
# min         1.000000                 0.000000                 0.000000
# 25%     25509.000000              5400.000000              7260.000000
# 50%     51017.000000              8000.000000             11500.000000
# 75%     76525.000000             13600.000000             20975.000000
# max    102033.000000            240000.000000            800000.000000
#
#        Modal Price (Rs./Quintal)
# count              102033.000000
# mean                15673.062049
# std                 21880.263649
# min                     0.000000
# 25%                  6500.000000
# 50%                 10050.000000
# 75%                 17899.000000
# max                350000.000000

# %%
df19.isna().sum()
# Out:
# Sl no.                       0
# District Name                0
# Market Name                  0
# Commodity                    0
# Variety                      0
# Grade                        0
# Min Price (Rs./Quintal)      0
# Max Price (Rs./Quintal)      0
# Modal Price (Rs./Quintal)    0
# Price Date                   0
# dtype: int64

# %%
df19.duplicated().sum()
# Out:
# np.int64(0)

# %%
df19.nunique()
# Out:
# Sl no.                       102033
# District Name                   182
# Market Name                     438
# Commodity                         7
# Variety                          40
# Grade                             4
# Min Price (Rs./Quintal)        7646
# Max Price (Rs./Quintal)       10975
# Modal Price (Rs./Quintal)     12063
# Price Date                     1258
# dtype: int64

# %%
print(df19.Commodity)
# Out:
# 0         Cinamon(Dalchini)
# 1         Cinamon(Dalchini)
# 2         Cinamon(Dalchini)
# 3         Cinamon(Dalchini)
# 4         Cinamon(Dalchini)
#                 ...
# 102028      Corriander seed
# 102029      Corriander seed
# 102030      Corriander seed
# 102031      Corriander seed
# 102032      Corriander seed
# Name: Commodity, Length: 102033, dtype: object

# %%
print(df19["Commodity"].unique())
# Out:
# ['Cinamon(Dalchini)' 'Dry Chillies' 'Cardamoms' 'Turmeric' 'Nutmeg'
#  'Cummin Seed(Jeera)' 'Corriander seed']

# %%
print("Categories in 'Grade' variable:  ",end=" ")
print(df19['Grade'].unique())
# Out:
# Categories in 'Grade' variable:   ['FAQ' 'Medium' 'Small' 'Large']

# %%
print("Categories in'Variety' variable:",end=" " )
print(df19['Variety'].unique())
# Out:
# Categories in'Variety' variable: ['Cinamon(Dalchini)' 'Other' 'Guntur' 'Red' 'White' 'Red New' 'Red Top'
#  '1st Sort' 'Local' 'Dry' 'Dry Chillies' 'Bold 1' 'Byadgi' 'Mankattu'
#  'Dabbi' 'Kaddi' 'Talu' '2nd Sort' 'Desi' 'Single Patti' 'Big' 'Large'
#  'Finger' 'Bulb' 'Turmeric Stick' 'Turmeric' 'Rajapuri' 'Turmeric Round'
#  'Medium' 'Cummin Seed(Jeera)' 'Bold' 'Superfine' 'Common' 'Pili'
#  'A-1, Green' 'Coriander Seed' 'Full Green' 'Medium Green' 'Eagle'
#  'Badami Steam']

# %%
print("Categories in 'District Name' variable:     ",end=" " )
print(df19['District Name'].unique())
# Out:
# Categories in 'District Name' variable:      ['Chhindwara' 'Mumbai' 'Guntur' 'Anantapur' 'Kurnool' 'Bastar' 'Jashpur'
#  'North Goa' 'Dahod' 'Rajkot' 'Jamnagar' 'Dharwad' 'Hassan' 'Bangalore'
#  'Haveri' 'Kolar' 'Davangere' 'Gadag' 'Koppal' 'Bellary' 'Bagalkot'
#  'Mangalore(Dakshin Kannad)' 'Raichur' 'Mysore' 'Tumkur' 'Chikmagalur'
#  'Udupi' 'Kollam' 'Alappuzha' 'Malappuram' 'Dhar' 'Bishnupur'
#  'Imphal West' 'Imphal East' 'Thoubal' 'Longleng' 'Tuensang' 'Ganjam'
#  'Jajpur' 'Cuttack' 'Kalahandi' 'Jodhpur' 'Ariyalur' 'Erode'
#  'Thiruvannamalai' 'Coimbatore' 'Salem' 'Namakkal' 'Cuddalore'
#  'Ramanathapuram' 'Villupuram' 'Vellore' 'Mahbubnagar' 'Adilabad'
#  'Khammam' 'Warangal' 'Nizamabad' 'Hyderabad' 'Medak' 'Fatehpur' 'Amethi'
#  'Idukki' 'Rayagada' 'Kalimpong' 'Cuddapah' 'Surguja' 'Koria' 'Janjgir'
#  'Balrampur' 'Jammu' 'Bidar' 'Chamrajnagar' 'Thiruvananthapuram'
#  'Kottayam' 'Ernakulam' 'Shehdol' 'Datia' 'Dindori' 'Indore' 'Jabalpur'
# ...

# %%
print("Categories in 'promotion_usage' variable:     ",end=" " )
print(df19['promotion_usage'].unique())
# Out:
# Categories in 'promotion_usage' variable:      [0 1]

# %%
numeric_features = [feature for feature in df19.columns if df19[feature].dtype != 'O']
categorical_features = [feature for feature in df19.columns if df19[feature].dtype == 'O']

# %%
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 6 numerical features : ['id', 'age', 'income', 'purchase_amount', 'promotion_usage', 'satisfaction_score']
#
# We have 6 categorical features : ['gender', 'education', 'region', 'loyalty_status', 'purchase_frequency', 'product_category']

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 8))
plt.subplot(121)
sns.histplot(data=df19,x='education',bins=30,kde=True,color='g')
plt.subplot(122)
sns.histplot(data=df19,x='education',kde=True,hue='gender')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df19,x='income',kde=True,hue='education')
plt.subplot(142)
sns.histplot(data=df19[df19.education=='College'],x='income',kde=True,hue='gender')
plt.subplot(143)
sns.histplot(data=df19[df19.loyalty_status=='Gold'],x='income',kde=True,hue='gender')
plt.show()

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df19,x='purchase_amount',kde=True,hue='product_category')
plt.subplot(142)
ax =sns.histplot(data=df19[df19.region=='North'],x='purchase_frequency',kde=True,hue='product_category')
plt.subplot(143)
ax =sns.histplot(data=df19[df19.region=='South'],x='purchase_frequency',kde=True,hue='product_category')
plt.show()

# %%
plt.subplots(1,3,figsize=(20,5))
plt.subplot(141)
ax =sns.histplot(data=df19,x='product_category',kde=True,hue='purchase_frequency')
plt.subplot(142)
ax =sns.histplot(data=df19[df.satisfaction_score>=6],x='purchase_frequency',kde=True,hue='product_category')
plt.subplot(143)
ax =sns.histplot(data=df[df.promotion_usage==1],x='education',kde=True,hue='product_category')
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.subplot(1, 4, 1)
plt.title('Purchase Amount')
sns.violinplot(y='purchase_amount',data=df19,color='red',linewidth=3)
plt.subplot(1, 4, 2)
plt.title('AGE')
sns.violinplot(y='age',data=df19,color='green',linewidth=3)
plt.subplot(1, 4, 3)
plt.title('INCOME')
sns.violinplot(y='income',data=df19,color='blue',linewidth=3)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (30, 12)

plt.subplot(1, 5, 1)
size = df['gender'].value_counts()
labels = 'Female', 'Male'
color = ['red','green']


plt.pie(size, colors = color, labels = labels,autopct = '.%2f%%')
plt.title('GENDER', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 2)
size = df19['purchase_frequency'].value_counts()
labels = 'frequent', 'rare','occasional',
color = ['red', 'green', 'blue']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('PURCHASE FREQ', fontsize = 20)
plt.axis('off')



plt.subplot(1, 5, 3)
size = df19['loyalty_status'].value_counts()
labels = 'Gold', 'Regular', 'Silver'
color = ['red','green','blue']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Loyalty Status', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 4)
size = df['region'].value_counts()
labels = 'North', 'South', 'East', 'West'
color = ['red','green','blue','yellow']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Region', fontsize = 20)
plt.axis('off')


plt.subplot(1, 5, 5)
size = df['education'].value_counts()
labels = 'College','High School','Bachelor','Masters'
color = ['red', 'green', 'blue', 'cyan','orange','grey']

plt.pie(size, colors = color,labels = labels,autopct = '.%2f%%')
plt.title('Education', fontsize = 20)
plt.axis('off')


plt.tight_layout()
plt.grid()

plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go

# %%
fig = px.scatter(df19, x="purchase_amount", y="purchase_frequency", color = "region")
fig.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='age', y='income', data=df19)
plt.title('AGE')
plt.xlabel('Concerned Region')
plt.ylabel('income(in Rs.) ')
plt.show()

# %%
# Selecting only numerical columns
numeric_cols = df19.select_dtypes(include=['float64', 'int64'])

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# Import required libraries
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
y_train.shape
# Out:
# (2100,)

# %%
y_test.shape
# Out:
# (900,)

# %%
df19 = linear.LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_47400\1553450040.py in ?()
# ----> 1 df19 = df19.LinearRegression()
#
# c:\Users\soura\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'LinearRegression'
